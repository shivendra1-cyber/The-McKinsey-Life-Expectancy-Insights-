# %% [markdown]
# <a href="https://colab.research.google.com/github/shivendra1-cyber/The-McKinsey-Life-Expectancy-Insights-/blob/main/McKinsey_LifeExpentancy_Insights1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
import numpy as np

# %% [markdown]
# HOW TO DOWNLOAD DATA

# %%
 # !gdown 1E3bwvYGf1ig32RmcYiWc0IXPN-mD_bI_
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1E3bwvYGf1ig32RmcYiWc0IXPN-mD_bI_
# To: /content/mckinsey.csv
# 100% 83.8k/83.8k [00:00<00:00, 65.7MB/s]

# %%
df=pd.read_csv("mckinsey.csv") # dataframe
df
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1699     Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1700     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
#
# [1704 rows x 6 columns]

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# df.shape

# %%
df["country"] # dataframe is similar to dictionary in multiple ways
# Out:
# 0       Afghanistan
# 1       Afghanistan
# 2       Afghanistan
# 3       Afghanistan
# 4       Afghanistan
#            ...
# 1699       Zimbabwe
# 1700       Zimbabwe
# 1701       Zimbabwe
# 1702       Zimbabwe
# 1703       Zimbabwe
# Name: country, Length: 1704, dtype: object

# %%
type(df["country"])
# Out:
# pandas.core.series.Series

# %% [markdown]
# FIND OUT DETAILS AND DATA TYPE OF EVERY COLUMN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1704 entries, 0 to 1703
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   country     1704 non-null   object
#  1   year        1704 non-null   int64
#  2   population  1704 non-null   int64
#  3   continent   1704 non-null   object
#  4   life_exp    1704 non-null   float64
#  5   gdp_cap     1704 non-null   float64
# dtypes: float64(2), int64(2), object(2)
# memory usage: 80.0+ KB

# %% [markdown]
# HOW TO PRINT COUPLE OF TOP ROWS  OF THE DATA SET

# %%
df.head()
# Out:
#        country  year  population continent  life_exp     gdp_cap
# 0  Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1  Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2  Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3  Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4  Afghanistan  1972    13079460      Asia    36.088  739.981106

# %% [markdown]
# HOW TO PRINT COUPLE OF BOTTOM ROWS OF THE DATA SET

# %%
df.tail()
# Out:
#        country  year  population continent  life_exp     gdp_cap
# 1699  Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1700  Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701  Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702  Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703  Zimbabwe  2007    12311143    Africa    43.487  469.709298

# %% [markdown]
# PRINT TOP 3 ROWS OF DATA SET

# %%
df.head(3)
# Out:
#        country  year  population continent  life_exp     gdp_cap
# 0  Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1  Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2  Afghanistan  1962    10267083      Asia    31.997  853.100710

# %% [markdown]
# CREATE DATA FROM SCRATCH

# %%
#CREATE DATA FROM SCRATCH
# 1. ROW ORIENTED APPROACH- LIST OF ROWS 
# 2. COLUMN ORIENTED APPROACH -DICTIONARY

# %%
pd.DataFrame([["Afghanistan",1952,8425333,"Asia",28.801,779.4453145],["Afghanistan",1957,9240934,"Asia",30.332,820.8530296],["Afghanistan",1962,10267083,"Asia",31.997,853.10071]], columns= ['country','year','population','continent','life_exp','gdp_cap'])
# Out:
#        country  year  population continent  life_exp     gdp_cap
# 0  Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1  Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2  Afghanistan  1962    10267083      Asia    31.997  853.100710

# %% [markdown]
# pd.DataFrame({'country':['Afghanistan','Afghanistan'],'year':['1952','1957'],'population':['842533','9240934'],'continent':['Asia','Asia']})

# %%
pd.DataFrame({'country':['Afghanistan','Afghanistan'],'year':['1952','1957'],'population':['842533','9240934'],'continent':['Asia','Asia'],'life_exp':[28.801,30.322]})
# Out:
#        country  year population continent  life_exp
# 0  Afghanistan  1952     842533      Asia    28.801
# 1  Afghanistan  1957    9240934      Asia    30.322

# %%
df.head(3)
# Out:
#        country  year  population continent  life_exp     gdp_cap
# 0  Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1  Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2  Afghanistan  1962    10267083      Asia    31.997  853.100710

# %%
# represent data in one row
pd.DataFrame([['Afghanistan' ,	1952 ,	8425333	,'Asia'	,28.801	,779.445314]],columns=['country' ,	'year','	population',	'continent',	'life_exp',	'gdp_cap'])
# Out:
#        country  year  \tpopulation continent  life_exp     gdp_cap
# 0  Afghanistan  1952       8425333      Asia    28.801  779.445314

# %% [markdown]
# print all the column names from data set

# %%
df.columns
# Out:
# Index(['country', 'year', 'population', 'continent', 'life_exp', 'gdp_cap'], dtype='object')

# %% [markdown]
# how to access  particular column

# %%
df['country']
# Out:
# 0       Afghanistan
# 1       Afghanistan
# 2       Afghanistan
# 3       Afghanistan
# 4       Afghanistan
#            ...
# 1699       Zimbabwe
# 1700       Zimbabwe
# 1701       Zimbabwe
# 1702       Zimbabwe
# 1703       Zimbabwe
# Name: country, Length: 1704, dtype: object

# %%
# how to access multiple clumns at a time 
df[['country','life_exp']]
# Out:
#           country  life_exp
# 0     Afghanistan    28.801
# 1     Afghanistan    30.332
# 2     Afghanistan    31.997
# 3     Afghanistan    34.020
# 4     Afghanistan    36.088
# ...           ...       ...
# 1699     Zimbabwe    62.351
# 1700     Zimbabwe    60.377
# 1701     Zimbabwe    46.809
# 1702     Zimbabwe    39.989
# 1703     Zimbabwe    43.487
#
# [1704 rows x 2 columns]

# %%
# check that we will get a data frame or  not
df[['country']]
# Out:
#           country
# 0     Afghanistan
# 1     Afghanistan
# 2     Afghanistan
# 3     Afghanistan
# 4     Afghanistan
# ...           ...
# 1699     Zimbabwe
# 1700     Zimbabwe
# 1701     Zimbabwe
# 1702     Zimbabwe
# 1703     Zimbabwe
#
# [1704 rows x 1 columns]

# %% [markdown]
# find out all unique country name in the data set

# %%
df['country'].unique()
# Out:
# array(['Afghanistan', 'Albania', 'Algeria', 'Angola', 'Argentina',
#        'Australia', 'Austria', 'Bahrain', 'Bangladesh', 'Belgium',
#        'Benin', 'Bolivia', 'Bosnia and Herzegovina', 'Botswana', 'Brazil',
#        'Bulgaria', 'Burkina Faso', 'Burundi', 'Cambodia', 'Cameroon',
#        'Canada', 'Central African Republic', 'Chad', 'Chile', 'China',
#        'Colombia', 'Comoros', 'Congo, Dem. Rep.', 'Congo, Rep.',
#        'Costa Rica', "Cote d'Ivoire", 'Croatia', 'Cuba', 'Czech Republic',
#        'Denmark', 'Djibouti', 'Dominican Republic', 'Ecuador', 'Egypt',
#        'El Salvador', 'Equatorial Guinea', 'Eritrea', 'Ethiopia',
#        'Finland', 'France', 'Gabon', 'Gambia', 'Germany', 'Ghana',
#        'Greece', 'Guatemala', 'Guinea', 'Guinea-Bissau', 'Haiti',
#        'Honduras', 'Hong Kong, China', 'Hungary', 'Iceland', 'India',
#        'Indonesia', 'Iran', 'Iraq', 'Ireland', 'Israel', 'Italy',
#        'Jamaica', 'Japan', 'Jordan', 'Kenya', 'Korea, Dem. Rep.',
# ...

# %% [markdown]
# find out count of all unique countries

# %%
df['country'].value_counts()
# Out:
# Afghanistan          12
# Pakistan             12
# New Zealand          12
# Nicaragua            12
# Niger                12
#                      ..
# Eritrea              12
# Equatorial Guinea    12
# El Salvador          12
# Egypt                12
# Zimbabwe             12
# Name: country, Length: 142, dtype: int64

# %%
np.unique(df['country'], return_counts='True')
# Out:
# (array(['Afghanistan', 'Albania', 'Algeria', 'Angola', 'Argentina',
#         'Australia', 'Austria', 'Bahrain', 'Bangladesh', 'Belgium',
#         'Benin', 'Bolivia', 'Bosnia and Herzegovina', 'Botswana', 'Brazil',
#         'Bulgaria', 'Burkina Faso', 'Burundi', 'Cambodia', 'Cameroon',
#         'Canada', 'Central African Republic', 'Chad', 'Chile', 'China',
#         'Colombia', 'Comoros', 'Congo, Dem. Rep.', 'Congo, Rep.',
#         'Costa Rica', "Cote d'Ivoire", 'Croatia', 'Cuba', 'Czech Republic',
#         'Denmark', 'Djibouti', 'Dominican Republic', 'Ecuador', 'Egypt',
#         'El Salvador', 'Equatorial Guinea', 'Eritrea', 'Ethiopia',
#         'Finland', 'France', 'Gabon', 'Gambia', 'Germany', 'Ghana',
#         'Greece', 'Guatemala', 'Guinea', 'Guinea-Bissau', 'Haiti',
#         'Honduras', 'Hong Kong, China', 'Hungary', 'Iceland', 'India',
#         'Indonesia', 'Iran', 'Iraq', 'Ireland', 'Israel', 'Italy',
# ...

# %%
np.unique(df['country'], return_counts=True)
# Out:
# (array(['Afghanistan', 'Albania', 'Algeria', 'Angola', 'Argentina',
#         'Australia', 'Austria', 'Bahrain', 'Bangladesh', 'Belgium',
#         'Benin', 'Bolivia', 'Bosnia and Herzegovina', 'Botswana', 'Brazil',
#         'Bulgaria', 'Burkina Faso', 'Burundi', 'Cambodia', 'Cameroon',
#         'Canada', 'Central African Republic', 'Chad', 'Chile', 'China',
#         'Colombia', 'Comoros', 'Congo, Dem. Rep.', 'Congo, Rep.',
#         'Costa Rica', "Cote d'Ivoire", 'Croatia', 'Cuba', 'Czech Republic',
#         'Denmark', 'Djibouti', 'Dominican Republic', 'Ecuador', 'Egypt',
#         'El Salvador', 'Equatorial Guinea', 'Eritrea', 'Ethiopia',
#         'Finland', 'France', 'Gabon', 'Gambia', 'Germany', 'Ghana',
#         'Greece', 'Guatemala', 'Guinea', 'Guinea-Bissau', 'Haiti',
#         'Honduras', 'Hong Kong, China', 'Hungary', 'Iceland', 'India',
#         'Indonesia', 'Iran', 'Iraq', 'Ireland', 'Israel', 'Italy',
# ...

# %% [markdown]
# renaming of columns

# %%
df.rename({'population':'Population','country':'Country'}, axis=1)
# Out:
#           Country  year  Population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1699     Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1700     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
#
# [1704 rows x 6 columns]

# %% [markdown]
# check out the names in real data frame

# %%
df
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1699     Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1700     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
#
# [1704 rows x 6 columns]

# %% [markdown]
# observation- names are not changed in real data *frame*

# %% [markdown]
# reason - pandas uses functional programing paradigm to keep data and operationas performed over that separately

# %% [markdown]
# try to make change in real data set

# %%
df=df.rename({'population':'Population','country':'Country'}, axis=1)

# %%
df
# Out:
#           Country  year  Population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1699     Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1700     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
#
# [1704 rows x 6 columns]

# %%
df['Country']
# Out:
# 0       Afghanistan
# 1       Afghanistan
# 2       Afghanistan
# 3       Afghanistan
# 4       Afghanistan
#            ...
# 1699       Zimbabwe
# 1700       Zimbabwe
# 1701       Zimbabwe
# 1702       Zimbabwe
# 1703       Zimbabwe
# Name: Country, Length: 1704, dtype: object

# %%
#same manner
df.Country #its not recommended method becauses 1. roll number 2.shape
# Out:
# 0       Afghanistan
# 1       Afghanistan
# 2       Afghanistan
# 3       Afghanistan
# 4       Afghanistan
#            ...
# 1699       Zimbabwe
# 1700       Zimbabwe
# 1701       Zimbabwe
# 1702       Zimbabwe
# 1703       Zimbabwe
# Name: Country, Length: 1704, dtype: object

# %% [markdown]
# how to delete a column from data set

# %%
df.drop('continent', axis =1) # continent will get deleted
# Out:
#           Country  year  Population  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333    28.801  779.445314
# 1     Afghanistan  1957     9240934    30.332  820.853030
# 2     Afghanistan  1962    10267083    31.997  853.100710
# 3     Afghanistan  1967    11537966    34.020  836.197138
# 4     Afghanistan  1972    13079460    36.088  739.981106
# ...           ...   ...         ...       ...         ...
# 1699     Zimbabwe  1987     9216418    62.351  706.157306
# 1700     Zimbabwe  1992    10704340    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    43.487  469.709298
#
# [1704 rows x 5 columns]

# %% [markdown]
# to make changes visible in original data set

# %%
df.drop('continent', axis =1, inplace=True)

# %%
df # csv file remains intact df is just memory
# Out:
#           Country  year  Population  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333    28.801  779.445314
# 1     Afghanistan  1957     9240934    30.332  820.853030
# 2     Afghanistan  1962    10267083    31.997  853.100710
# 3     Afghanistan  1967    11537966    34.020  836.197138
# 4     Afghanistan  1972    13079460    36.088  739.981106
# ...           ...   ...         ...       ...         ...
# 1699     Zimbabwe  1987     9216418    62.351  706.157306
# 1700     Zimbabwe  1992    10704340    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    43.487  469.709298
#
# [1704 rows x 5 columns]

# %% [markdown]
# update year by 5

# %%
df['year']
# Out:
# 0       1952
# 1       1957
# 2       1962
# 3       1967
# 4       1972
#         ...
# 1699    1987
# 1700    1992
# 1701    1997
# 1702    2002
# 1703    2007
# Name: year, Length: 1704, dtype: int64

# %%
df['year']+5
# Out:
# 0       1957
# 1       1962
# 2       1967
# 3       1972
# 4       1977
#         ...
# 1699    1992
# 1700    1997
# 1701    2002
# 1702    2007
# 1703    2012
# Name: year, Length: 1704, dtype: int64

# %% [markdown]
# to make changes in original data frame reassign df

# %%
df['year']=df['year']+5

# %%
df
# Out:
#           Country  year  Population  life_exp     gdp_cap
# 0     Afghanistan  1957     8425333    28.801  779.445314
# 1     Afghanistan  1962     9240934    30.332  820.853030
# 2     Afghanistan  1967    10267083    31.997  853.100710
# 3     Afghanistan  1972    11537966    34.020  836.197138
# 4     Afghanistan  1977    13079460    36.088  739.981106
# ...           ...   ...         ...       ...         ...
# 1699     Zimbabwe  1992     9216418    62.351  706.157306
# 1700     Zimbabwe  1997    10704340    60.377  693.420786
# 1701     Zimbabwe  2002    11404948    46.809  792.449960
# 1702     Zimbabwe  2007    11926563    39.989  672.038623
# 1703     Zimbabwe  2012    12311143    43.487  469.709298
#
# [1704 rows x 5 columns]

# %% [markdown]
# now calculate gdp of all the nations mentioned in the data  set and show it in new column

# %%
df['gdp']= df['gdp_cap']*df['Population']

# %%
df #gdp is visible in a new column gdp
# Out:
#           Country  year  Population  life_exp     gdp_cap           gdp
# 0     Afghanistan  1957     8425333    28.801  779.445314  6.567086e+09
# 1     Afghanistan  1962     9240934    30.332  820.853030  7.585449e+09
# 2     Afghanistan  1967    10267083    31.997  853.100710  8.758856e+09
# 3     Afghanistan  1972    11537966    34.020  836.197138  9.648014e+09
# 4     Afghanistan  1977    13079460    36.088  739.981106  9.678553e+09
# ...           ...   ...         ...       ...         ...           ...
# 1699     Zimbabwe  1992     9216418    62.351  706.157306  6.508241e+09
# 1700     Zimbabwe  1997    10704340    60.377  693.420786  7.422612e+09
# 1701     Zimbabwe  2002    11404948    46.809  792.449960  9.037851e+09
# 1702     Zimbabwe  2007    11926563    39.989  672.038623  8.015111e+09
# 1703     Zimbabwe  2012    12311143    43.487  469.709298  5.782658e+09
#
# [1704 rows x 6 columns]

# %%
df['own']=[i for i in range(1704)]

# %%
df
# Out:
#           Country  year  Population  life_exp     gdp_cap           gdp   own
# 0     Afghanistan  1957     8425333    28.801  779.445314  6.567086e+09     0
# 1     Afghanistan  1962     9240934    30.332  820.853030  7.585449e+09     1
# 2     Afghanistan  1967    10267083    31.997  853.100710  8.758856e+09     2
# 3     Afghanistan  1972    11537966    34.020  836.197138  9.648014e+09     3
# 4     Afghanistan  1977    13079460    36.088  739.981106  9.678553e+09     4
# ...           ...   ...         ...       ...         ...           ...   ...
# 1699     Zimbabwe  1992     9216418    62.351  706.157306  6.508241e+09  1699
# 1700     Zimbabwe  1997    10704340    60.377  693.420786  7.422612e+09  1700
# 1701     Zimbabwe  2002    11404948    46.809  792.449960  9.037851e+09  1701
# 1702     Zimbabwe  2007    11926563    39.989  672.038623  8.015111e+09  1702
# 1703     Zimbabwe  2012    12311143    43.487  469.709298  5.782658e+09  1703
#
# [1704 rows x 7 columns]

# %%
df[['gdp','Country']] # order has been changed
# Out:
#                gdp      Country
# 0     6.567086e+09  Afghanistan
# 1     7.585449e+09  Afghanistan
# 2     8.758856e+09  Afghanistan
# 3     9.648014e+09  Afghanistan
# 4     9.678553e+09  Afghanistan
# ...            ...          ...
# 1699  6.508241e+09     Zimbabwe
# 1700  7.422612e+09     Zimbabwe
# 1701  9.037851e+09     Zimbabwe
# 1702  8.015111e+09     Zimbabwe
# 1703  5.782658e+09     Zimbabwe
#
# [1704 rows x 2 columns]
